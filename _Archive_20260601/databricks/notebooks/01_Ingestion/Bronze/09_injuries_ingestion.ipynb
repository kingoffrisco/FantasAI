# %% [markdown]
# # 🏥 FantasAI Injuries Ingestion
#
# **DEPRECATED**: This notebook is replaced by **07_news_ingestion** (Sleeper API Consolidated)
#
# **Reason for deprecation:**
# - Sleeper API provides injury data directly (no need for Cloudflare Worker proxy)
# - 07_news_ingestion fetches ALL Sleeper data (players, news, injuries, trending) in one run
# - New table schema: `main.fantasai.silver_injury_reports`
#
# **Migration:**
# - Old table: `main.fantasai.silver_injuries` (via Cloudflare Worker)
# - New table: `main.fantasai.silver_injury_reports` (direct from Sleeper)
# - Use **07_news_ingestion** for all future injury data
#
# **Keep Cloudflare Worker for:**
# - Frontend API requests (CORS, caching, aggregation)
# - NOT for backend ingestion (go direct to Sleeper)
#
# ---
#
# ## Quick Reference: Use 07_news_ingestion Instead
#
# This notebook is kept for historical reference only.

# %%
# DEPRECATED - See 07_news_ingestion
import requests
from pyspark.sql import Row
from pyspark.sql import functions as F

print("⚠️  DEPRECATED: This notebook is replaced by 07_news_ingestion")
print("")
print("Please use: /Repos/.../Bronze/07_news_ingestion")
print("New table: main.fantasai.silver_injury_reports")
print("")
print("This notebook uses Cloudflare Worker proxy.")
print("The new approach goes direct to Sleeper API for backend ingestion.")

# %%
# DEPRECATED - Tables created by 07_news_ingestion
print("Old tables (this notebook): main.fantasai.bronze_injuries, main.fantasai.silver_injuries")
print("New tables (07_news_ingestion): main.fantasai.bronze_player_news_raw, main.fantasai.silver_injury_reports")
print("")
print("Run 07_news_ingestion to populate new tables.")

# %%
# DEPRECATED - Cloudflare Worker approach (replaced by direct Sleeper API)
print("⚠️  This cell is deprecated")
print("")
print("Old approach: Fetch from Cloudflare Worker")
print("New approach: Direct to Sleeper API (see 07_news_ingestion)")

# %%
# DEPRECATED
print("⚠️  This cell is deprecated - use 07_news_ingestion")

# %%
# DEPRECATED
print("⚠️  This cell is deprecated - use 07_news_ingestion")

# %%
# DEPRECATED
print("⚠️  This cell is deprecated - use 07_news_ingestion")
